# %% [raw]
# Using filtered_data1703.csv, performing further filtering
#
# Starting point: 291139 tweets
# End result: 162008 tweets
#
# Saved in data/filter/en/filtered_data0604.csv

# %%
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as plt


# Filepaths
fp = "data/filter/en/filtered_data1703.csv"

# Read the files
ht = pd.read_csv(fp)
len(ht)
# Out:
# 291139

# %% [markdown]
# ## Remove diamond

# %%
to_remove = ht.loc[ht["text"].str.lower().str.contains("diamond")]

# %%
len(to_remove)
#to_remove.loc[to_remove["text"].str.lower().str.contains("dam")]["text"].to_list()
# Out:
# 1532

# %%
ht = pd.concat([ht, to_remove]).drop_duplicates(keep=False)
len(ht)
# Out:
# 289607

# %% [markdown]
# ## Remove nile+jewelry

# %%
to_remove = ht.loc[ht["text"].str.lower().str.contains(r'^(?=.*nile)(?=.*jewelry)')]

# %%
to_remove.loc[to_remove["text"].str.lower().str.contains("egypt")]["text"].to_list()
# Out:
# ['#Ancient #Egypt #Nile #Bead #Jewelry #Egyptian #Blue #Faience w/ #COA 2500-4000 #Years Old - https://t.co/keL728CT8d https://t.co/SX8tqVYXFj',
#  '#Ancient #Egypt #Nile #Bead #Jewelry #Egyptian #Blue #Faience w/ #COA 2500-4000 #Years Old - https://t.co/TPWk9Y425e',
#  '#Ancient #Egypt #Nile #Bead #Jewelry #Egyptian #Blue #Faience w/ #COA 2500-4000 #Years Old - https://t.co/GZgJ8XvqOs https://t.co/ImFJPqSqJk',
#  'A lazy Sunday boat expedition across the Nile River to Elephantine Island. Jump off a pier onto the small blue boat. We were thrilled to have a local jewelry maker come along with us; and yes, of course, I bought a few of his treasures.#elephantine #Egypt #Aswan #Nile https://t.co/PJEdYEbvrV',
# ...

# %%
ht = pd.concat([ht, to_remove]).drop_duplicates(keep=False)
len(ht)
# Out:
# 288859

# %% [markdown]
# ## 2011

# %%
y11 = ht.loc[ht["created_at"].str.lower().str.contains("2011")]#["text"].to_list()

# %% [markdown]
# ### tigray from 2011

# %%
#y11 = ht.loc[ht["created_at"].str.lower().str.contains("2011")]#["text"].to_list()
to_remove11 = y11.loc[y11["text"].str.lower().str.contains("tigray")].copy()

#ht = pd.concat([ht, to_remove11]).drop_duplicates(keep=False)
len(to_remove11)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 27

# %% [markdown]
# ### gerd from 2011

# %%
#y11 = ht.loc[ht["created_at"].str.lower().str.contains("2011")]#["text"].to_list()
to_remove11 = pd.concat([to_remove11, y11.loc[y11["text"].str.lower().str.contains("gerd")]]).copy()

#ht = pd.concat([ht, to_remove11]).drop_duplicates(keep=False).copy()
len(to_remove11)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 563

# %% [markdown]
# ### bluenile from 2011

# %%
#y11 = ht.loc[ht["created_at"].str.lower().str.contains("2011")]#["text"].to_list()
to_remove11 = pd.concat([to_remove11, y11.loc[y11["text"].str.lower().str.contains("bluenile")]]).copy()

#ht = pd.concat([ht, to_remove11]).drop_duplicates(keep=False).copy()
len(to_remove11)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 1678

# %% [markdown]
# ### Further 2011

# %%
#y11 = ht.loc[ht["created_at"].str.lower().str.contains("2011")]#["text"].to_list()
to_keep1 = y11.loc[y11["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y11.loc[y11["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y11.loc[y11["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y11.loc[y11["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource")].copy()
to_keep5 = y11.loc[y11["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y11.loc[y11["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()

junk = pd.concat([y11, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6]).drop_duplicates(keep=False).copy()
print(len(junk), len(y11), len(y11) - len(junk))
# Out:
# 4079 4614 535

# %%
#junk.loc[y11["created_at"].str.lower().str.contains("2011-04")]["text"].to_list()
junk.loc[junk["text"].str.lower().str.contains("dams")]["text"].to_list()
# Out:
# []

# %%
junk.sample(n=10)["text"].to_list()
# Out:
# ['Reports from Damazine #BlueNile describe shelling of residential areas &bodies in the streets #Sudan',
#  "My friend @warshocked also has #GERD. You're next @akosiburayan. :) bwahahaha",
#  "#GERD attack! I can't sleep :(",
#  'Please RT Refugees tell of bombing in Sudan’s Blue Nile State: Part 1 http://t.co/FXsBx3Ho #Sudan #BlueNile #Conflict @amnesty @AmnestyUK',
#  'http://www.pulist.net/egypt-11650000-travel-map.html #nile #river #valley #international Egypt 1:1,650,000 Travel Map',
#  'Sue Bird, @BarackObama & @SwinCash show off their #BlueNile bling today at the White House!  http://t.co/SXhCUJD via @twitpic',
#  'Oh I love this #nile esp when u r with so u love listening the great #Fayrouz',
#  '10 Tips to Prevent #GERD, via Johns Hopkins http://ow.ly/6wkcy',
#  '#Sudan risks burgeoning civil wars if no urgent actions taken: report  http://t.co/0blsBTBA #African #Darfur #Kordofan #BlueNile #war',
# ...

# %% [markdown]
# ### Remove junk+to_remove11

# %%
ht = pd.concat([ht, to_remove11, junk]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 284771

# %% [markdown]
# ## 2012

# %%
y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove tigray from 2012

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")].copy()#["text"].to_list()
to_remove12 = y12.loc[y12["text"].str.lower().str.contains("tigray")].copy()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove12)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 51

# %% [markdown]
# ### Remove bluenile

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2011")]#["text"].to_list()
to_remove12 = pd.concat([to_remove12, y12.loc[y12["text"].str.lower().str.contains("bluenile")]]).copy()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove12)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 1808

# %% [markdown]
# ### Remove sudan+kordofan from 2012

# %%
to_remove12 = pd.concat([to_remove12, y12.loc[y12["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]]).copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove12)
# Out:
# 2057

# %% [markdown]
# ### Remove gerd from 2012

# %%
to_remove12 = pd.concat([to_remove12, y12.loc[y12["text"].str.lower().str.contains("gerd")]]).copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove12)
# Out:
# 3075

# %% [markdown]
# ### Further 2012

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y12.loc[y12["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y12.loc[y12["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y12.loc[y12["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y12.loc[y12["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation")].copy()
to_keep5 = y12.loc[y12["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y12.loc[y12["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6]).drop_duplicates().copy()
junk12 = pd.concat([y12, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6]).drop_duplicates(keep=False).copy()
print(len(junk12), len(y12), len(to_keep))
# Out:
# 8270 8765 495

# %%
junk12.loc[junk12["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*africa)')]["text"].to_list()
# Out:
# []

# %%
to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")]["text"].to_list()
# Out:
# ["@RyanMadanickMD: I'm getting our past EWTE videos online. Your  2011 talk on #GERD is up - excellent patient resource: http://t.co/4e7qTwEG",
#  'In #Ethiopia the Grand Ethiopian #Renaissance #Dam (#GERD) is 11% done and is progressing on track | AllAfrica: http://t.co/LHcXd7dP',
#  'New blog post: #GERD Awareness Week, resources for adults and #children, often overlaps #IBS. http://t.co/qim6h8dk Thanks @IFFGD @bbolenibs',
#  "Today's spotlight: Strategic Analysis: Chinese investment in the Nile Basin. http://t.co/M4hALCng #Egypt #Ethiopia #GERD #Morsi",
#  'Via #Meles #Zenawi The Grand #Ethiopian Renaissance Dam #GERD : Transforming the #Nile from Fixation to Cooperation \r\nhttp://t.co/2eeHLnZM',
#  'The Grand #Ethiopia Renaissance Dam #GERD : A Dam of Mega-Benefits\r\n#Meles #Zenawi\r\nhttp://t.co/TPqZtrZo',
#  '#Ethiopia is Driving to Complete its Massive $4.8 Billion USD Grand Ethiopian Renaissance Dam #GERD on the Blue Nile\r\nhttp://t.co/LOqce9M9',
# ...

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove12, junk12]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 276480

# %% [markdown]
# ## 2013

# %%
y13 = ht.loc[ht["created_at"].str.lower().str.contains("2013")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove tigray

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")].copy()#["text"].to_list()
to_remove13 = y13.loc[y13["text"].str.lower().str.contains("tigray")].copy()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove13)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 158

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove13 = pd.concat([to_remove13, y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]]).copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove13)
# Out:
# 336

# %%
y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()
# Out:
# ['#SPLMN #rebels have to abandon #regimechange before talks, Sudanese official http://t.co/LFgMR6vq #Sudan #SouthKordofan #BlueNile',
#  '#Sudan and #SSudan meet and once again cloud issues of war in #SouthKordofan and #BlueNile',
#  "MT @SudanSentinel: ' @HRW reports indiscriminate bombardment, #HR abuses in #Sudan's S.Kordofan #BlueNile http://t.co/OnwmCkm6",
#  'Appalling humanitarian situation in #SouthKordofan &amp; #BlueNile affecting 900,000 people http://t.co/DVqFtXgA #UNSC #Sudan',
#  'OCHA: "Desperate" humanitarian situation in #Sudan\'s #SouthKordofan &amp; #BlueNile states amid intensified fighting http://t.co/tIX6tzu6 #R2P',
#  '#Sudan: as fighting intensifies in South #Kordofan + #BlueNile @UNOCHA states lack of access is "just not acceptable" http://t.co/AqfLzobS',
#  '#SPLMN tells #Germany to cancel #Sudan investment conference http://t.co/mzxvTfcp #SouthKordofan #BlueNile',
# ...

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y13.loc[y13["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()

to_remove13 = pd.concat([to_remove13, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove13)
# Out:
# 1380

# %%
temp = y13.loc[y13["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

# %%
temp["text"].sample(n=50).to_list()
# Out:
# ['For people from #Reynosa, #Mexico : 1974 #German #Munich #Muller #Stripes #Team #Gerd #Clothes #Event #Legend http://t.co/J9kc76MnxS',
#  '"Antireflux therapy for otitis media cannot be endorsed based on existing research". #gerd #pediatrics  http://t.co/MENJA59We5',
#  '"@DDWMeeting: Early pH test in #GERD may save $$$. @medpagetoday shares video from #DDW13 highlighting this data http://t.co/2S7J1vWCml"',
#  'Readers’ Chronicles : An Open Letter to Egyptians From #Ethiopia | \r\n#Nile #Egypt http://t.co/r0sElPU88f',
#  'Second. Just to boost my energy tonight. ☕️☕️😷💉🌙 #coffee #GERD #maygamotnaman LoL #NurseOnDuty #graveyard http://t.co/ayZWu6W376',
#  'Bigger than you : Adidas #Stripes 1970 #Gerd #Striker #Vegas #Addict #Soccer #Bomber #Football #Legend #Muller http://t.co/8rP5WrDTs0',
#  'How much do you know about #GERD? Some facts from @MedicineNet http://t.co/4zp3kknGjN',
# ...

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y13.loc[y13["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7]).drop_duplicates().copy()
junk13 = pd.concat([y13, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7]).drop_duplicates(keep=False).copy()
print(len(junk13), len(y13), len(to_keep))
# Out:
# 11233 13917 2684

# %%
junk13.tail(100)["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]
# Out:
# ['#Nile Aviation Airplanes\r\n\r\nhttp://t.co/yutqhqeap4',
#  '2 Ducks .....#Nile#Benha !! ^^ http://t.co/MyzwLUS2SX',
#  '#Nile Aviation Airplanes\r\n\r\nhttp://t.co/f7SrfwKsQn',
#  '#Nile Aviation Airplanes\r\n\r\nhttp://t.co/AaYBIyHlV1',
#  "#WhiteNile in #Sudan prepares 4 #refugee influx from #SouthSudan while '000s of #BlueNile refugees still in #Maban https://t.co/ddodsJmfBM",
#  'There was a girl who motivated me with the words written on the back of her sweatshirt-Be the change you want to see- #Cairo_runners #Nile',
#  'On ma way from #source of the #NILE. Here I come #kampalaCityYaffe @TheTrapKamp @edithrael @cyrajngati @RavesCafe @hipipo RT',
#  'Peep it. "@YoMcDuff: Check out @NILEMusicGroup artist @VAthaGray new single Bombay feat @MgaCzar #Nile http://t.co/cVTSyi6Sr8"',
#  '#Nile Aviation Airplanes\r\n\r\nhttp://t.co/dwfXeQRgtv',
#  'Sudanese #refugees in #SouthSudan facing difficult #humanitarian situation: #SPLMN http://t.co/EKt2MOZqEZ #SouthKordofan #BlueNile',
# ...

# %%
to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")]["text"].to_list()
# Out:
# ['#Ethiopia #Sabbahi #Hammad #GERD #NileDam #Egypt #Sudan We also say Water is thicker than Blood http://t.co/ewhgzCyPXTውሃ-ከደም-ይወፍራል/',
#  "#Water #Security: #Sudan &amp; #Egypt clash over #Ethiopia's #Nile #dam\r\n http://t.co/CABWuQR8aY #GERD",
#  "Ethiopian envoy lauds #Sudan's stance on #Nile dam, criticizes #Egypt http://t.co/GvAf6BatJW … #Ethiopia #Africa #BlueNile #GERD #Water",
#  "#HornAfrica: Ethiopian envoy lauds #Sudan's stance on #Nile dam, criticizes #Egypt http://t.co/Eyjd87yWPd #Ethiopia #Africa #GERD #Water",
#  "Ethiopian envoy lauds #Sudan's stance on #Nile dam, criticizes #Egypt http://t.co/nTykcK6yOa #Ethiopia #Africa #BlueNile #GERD #Water",
#  "#SouthSudan, the youngest African nation, backed #Ethiopia's natural right to use #Nile water. #Egypt needs a grip on the reality. #GERD.",
#  '#Egypt, #Ethiopia, &amp; #Sudan reportedly to begin consultations among Water Resources &amp; Foreign Ministers on #GERD http://t.co/jRSlvqxMns',
# ...

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove13, junk13]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 265225

# %% [markdown]
# ## 2014

# %%
y14 = ht.loc[ht["created_at"].str.lower().str.contains("2014")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove tigray

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")].copy()#["text"].to_list()
to_remove14 = y14.loc[y14["text"].str.lower().str.contains("tigray")]

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove14)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 228

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove14 = pd.concat([to_remove14, y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]]).copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove14)
# Out:
# 401

# %%
y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()
# Out:
# ['#SPLMN #rebels have to abandon #regimechange before talks, Sudanese official http://t.co/LFgMR6vq #Sudan #SouthKordofan #BlueNile',
#  '#Sudan and #SSudan meet and once again cloud issues of war in #SouthKordofan and #BlueNile',
#  "MT @SudanSentinel: ' @HRW reports indiscriminate bombardment, #HR abuses in #Sudan's S.Kordofan #BlueNile http://t.co/OnwmCkm6",
#  'Appalling humanitarian situation in #SouthKordofan &amp; #BlueNile affecting 900,000 people http://t.co/DVqFtXgA #UNSC #Sudan',
#  'OCHA: "Desperate" humanitarian situation in #Sudan\'s #SouthKordofan &amp; #BlueNile states amid intensified fighting http://t.co/tIX6tzu6 #R2P',
#  '#Sudan: as fighting intensifies in South #Kordofan + #BlueNile @UNOCHA states lack of access is "just not acceptable" http://t.co/AqfLzobS',
#  '#SPLMN tells #Germany to cancel #Sudan investment conference http://t.co/mzxvTfcp #SouthKordofan #BlueNile',
# ...

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()

to_remove14 = pd.concat([to_remove14, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove14)
# Out:
# 967

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
temp["text"].sample(n=50).to_list()
# Out:
# ['Presentation today by Dr Prateek Sharma in Argentina at #gastro2014 on RF therapy for #GERD @StrettaTherapy',
#  'RT “@TMCircle: Ulcer Medications can Cause Vitamin B12 Deficiency http://t.co/Lc5XD5roJi\r\n #GERD #Vitamindef”',
#  '#sleep problems such as #apnea could be behind your #GERD. Conquer it this #GERDWEEK : http://t.co/2DXobpnlWJ',
#  '@JaniceOnDisPlay thank you for this!!!! #caramel #chocolaterich #brownie 😊 yummy! And here comes my #gerd 😲😄 http://t.co/OhWFETniws',
#  'Hell yeah! 👌👍😊 #tummyache #kalamoseryosolol #painpaingoaway #constipated #GERD http://t.co/fmwLLW0ILL',
#  '@StrettaTherapy #GERD - New GI Technology: 8 gastroenterologists on the most exciting advancements http://t.co/CdkcreY6JE',
#  'A rich #smoothie, fruity drink, #kids going to love this one. http://t.co/kJS5Tv52Vy #Beverage #GERD #Recipe',
#  '@AdrianHodgkiss My daughter painted it when about 10 years ago. Only plate big enough for the cake! No #GERD (hooray!). Tastes amazing.',
# ...

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y14.loc[y14["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y14.loc[y14["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates().copy()
junk14 = pd.concat([y14, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates(keep=False).copy()
print(len(junk14), len(y14), len(to_keep))
# Out:
# 8513 10559 2046

# %%
junk14.loc[junk14["created_at"].str.contains("2014-05")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]
# Out:
# ['#NILE w/ #InfernalMajesty &amp; #Auroch tonight! Doors at 7:00pm @ Rickshaw Theatre http://t.co/7zglrNvYUT',
#  'New displacement in #Sudan’s #SouthKordofan and #BlueNile http://t.co/zoRFfkeazr',
#  'Last night Toubab Krewe was playing a show called "Steal Your Covers" at the #BlueNile. It was a Greatful Dead... http://t.co/2l2oiI3Vnd',
#  '#Nile #nile #LittleOchie #CheckThisOutOnWest145thStreetHarlemNYC. As I stood waiting for the… http://t.co/j3gzGZ57Cx',
#  '#GoodLuckNileOnTourUAE\rThe tour will be successful because of you #Nile #الجيش_النيلاوي',
#  '#Top500 News! #BlueNile posts a 6.8% sales increase in Q1 http://t.co/dTJvX5Y5dW',
#  'In honor of jazzfest our #tbt is us rockin the stage at the #bluenile on #frenchmenst last summer!… http://t.co/faQevrIm3L',
#  "Just want to share this..there's no dull moments with temengat #ptcounselling #GERD",
#  'Woke up with tummy and chest pain.. #GERD #FuckingBooze',
# ...

# %%
to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")]["text"].to_list()
# Out:
# ["Will #Ethiopia's #GrandRenaissanceDam #dry up the #Nile in #Egypt? http://t.co/xVrQKMCRhM via @sharethis #Gerd #water #conflict #Sudan",
#  'Dr Casaco of SIWI says #GERD makes more water available to #Sudan &amp; reduces evaporation in Egypt + solve sediment &amp; flood issues. #Ethiopia',
#  '8. Colonial era treaties between Egypt and British, and bn Egypt &amp; Sudan exclude #Ethiopia which contributes 85% of Nile water #GERD #Yilma',
#  'RT: @SudanTribune_EN: #Sudan to host #Nile water tripartite meeting in mid-August #Egypt http://t.co/dnkBBidYms … #GERD #Egypt #Ethiopia',
#  '#Sudan to host #Nile water tripartite meeting in mid-August http://t.co/ccYHyCiP5V #GERD #Egypt #Ethiopia',
#  '#Ethiopia and #Sudan set to launch joint #military operation http://t.co/Y41MxQb4d2 #Egypt #Nile #GERD #Water',
#  '#Sudan mediating discussions about GERD in #Nile #water tripartite meeting w/ #Ethiopia and #Egypt held in Khartoum  http://t.co/GV05S3krNu',
# ...

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove14, junk14]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 256691

# %% [markdown]
# ## 2015

# %%
y15 = ht.loc[ht["created_at"].str.lower().str.contains("2015")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove tigray

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")].copy()#["text"].to_list()
to_remove15 = y15.loc[y15["text"].str.lower().str.contains("tigray")]

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove15)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 603

# %%
#y15.loc[y15["text"].str.lower().str.contains("tigray")]["text"].to_list()

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove15 = pd.concat([to_remove15, y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]]).copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove15)
# Out:
# 664

# %%
y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()
# Out:
# ["#Sudan's security agency has authority over a 'counter-insurgency' unit deployed in western #Darfur, #SouthKordofan, &amp; #BlueNile states.",
#  '#SPLM-N claims victory in #SouthKordofan, #BlueNile battles, #Sudan http://t.co/ELVu64vkMG',
#  '#SPLMN says it repulsed #SAF attacks in #SouthKordofan, #BlueNile http://t.co/tEkED6InAc #Sudan #Military',
#  'In #BlueNile and #Kordofan, #Sudan continues to bomb its citizens. Shame #Bashir shame. http://t.co/9TQBeQfHds via @reliefweb',
#  '#Sudan: Conflicts, #RightsAbuses of #MilitaryForces Intensify . http://t.co/rgbKV7iaKU #HRW #Darfur #BlueNile #SouthernKordofan',
#  'Constitutional amendments dash hopes for peace in #Sudan’s Two Areas: Arman http://t.co/kvITD4N8Lc #SouthKordofan #BlueNile #SPLMN',
#  '#MSF suspends operations in #Sudan conflict zones http://t.co/imUsER0xxD #Humanitarian #SouthKordofan #BlueNile #Darfur',
# ...

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y15.loc[y15["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()

to_remove15 = pd.concat([to_remove15, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove15)
# Out:
# 1384

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
temp["text"].sample(n=50).to_list()
# Out:
# ["RT https://t.co/6RCqkx6AE9 Don't let #GERD ruin your #Thanksgiving OR your #sleep. https://t.co/HYe6l0Vmaz #sleepmatters #sleephealth #re…",
#  '#HackerNews talks about #coffee love, caffeine anxiety, #sleep, #GERD, and @Dandy_Blend (as mentioned in article): http://t.co/IONJXx3ceE',
#  'in magnificent Istanbul. Here at the Euro Society of Neurogastroenterology &amp; Motility Congress #gerd http://t.co/DB3iQ89WYo',
#  'Tomorrow! #Gastroparesis FDA Drug Development Mtg Webcast 5/11 1-5PM EDT http://t.co/VgmehEMGiS #curegp #green4gp #GERD #IBS @FGIFYI',
#  'In pain #GERD',
#  'No effects #Cairo #Nile http://t.co/swuTqJMqEJ Coming soon the full #photogallery on #EgyptianChronicles #KodakAgfa',
#  'Musick Magazine NOWY NUMER! - https://t.co/jtOzKy8Eh6 #mgla #chelseawolfe #stararzeka #instantclassic #nile #mydyingbride #uncleacid',
#  "I love how when I need to find someone's house a squad of 5year olds will escort me. #Ethiopia #tigray #hospitality #thispeacecorpslife 🌍😍",
# ...

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y15.loc[y15["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y15.loc[y15["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates().copy()
junk15 = pd.concat([y15, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates(keep=False).copy()
print(len(junk15), len(y15), len(to_keep))
# Out:
# 8054 9691 1637

# %%
junk15.loc[junk15["created_at"].str.contains("2015-06")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]
# Out:
# ['Agaza!👍 #friends #good #weather #nile #thoughts #cool #first #day @ Left Bank https://t.co/3XoiEiTtnS',
#  "@XneuCom's account is temporarily unavailable because it violates the Twitter Media Policy. Learn more.",
#  'If your #GERD becomes a pain in the ass something terrible has happened.',
#  '#Nile publicarán “What hould Not Be Unearthed” en agosto http://t.co/4xiQsLp3I4',
#  'The view from the Sofitel Legend Old Cataract, Aswan. Photo: James Bedford #blooms #Nile #Egypt https://t.co/HflfcC3xez',
#  'Analysts Set #BlueNile Price Target at $33.50 (#Nasdaq:NILE) | sleekmoney http://t.co/iGT0nwVPDe #eyebalz #buzz #2minRead',
#  "There's plenty to learn when it comes to #GERD: http://t.co/z7MfRrEnDP",
#  "It's Monday. Get a fresh start. #mysitota #thesitotacollection #scents #candles #bluenile https://t.co/3OA1MXlvlv",
#  "Happy New Month Ma'am Of Life @NseIkpeEtim My greatest Inspiration #ProudAfricanWoman #RoleModel #HighlyTalented HaveAproductiveMonth #NILE",
# ...

# %%
to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")]["text"].to_list()
# Out:
# ["#SouthSudan: #Egypt proposes mini-dam in Jur Wau WBEG; response to #Ethiopia's #GERD? New phase of water conflict? http://t.co/qkVlfQzCgV",
#  'excusive interview wz Alemayehu Tegenu minster of water n energy  #Ethiopia #Egypt #sudan Nile #GERD http://t.co/StjfemEK0h',
#  'Can someone please explain to me what "water recourses" are? Why must we fail at detail? #GERD #Ethiopia #Sudan #EGY http://t.co/nN4CBb6enU',
#  "#Ethiopia's aggressive water diplomacy w #Egypt &amp; #Sudan is paying off. Congrats, @DrTedros &amp; @ALEMAYEHUTEGENU! #GERD http://t.co/fs4H0HOKoZ",
#  '#GERD on z Verge of solving the Nile Dilemma: #Sudan, #Egypt, #Ethiopia agree basis of Nile water deal http://t.co/46YdxkV25c via @YahooNews',
#  '#Ethiopia, #Sudan, and #Egypt Agree Basis of #Nile Water Deal! #Abay #GERD \r\n\r\nhttp://t.co/J3s55Dz0Vc',
#  'CNN: #Ethiopia|s $5bn project that could turn it into #Africa|s water powerhouse http://t.co/y7DRbkoa21 #GERD #Egypt #Sudan #Kenya #Tanzania',
# ...

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove15, junk15]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 248594

# %% [markdown]
# ## 2016

# %%
y16 = ht.loc[ht["created_at"].str.lower().str.contains("2016")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove tigray

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")].copy()#["text"].to_list()
to_remove16 = y16.loc[y16["text"].str.lower().str.contains("tigray")]

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove16)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 819

# %%
#y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*tigray)(?=.*nile)')]["text"].to_list()

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove16 = pd.concat([to_remove16, y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]]).copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove16)
# Out:
# 937

# %%
#y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y16.loc[y16["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()

to_remove16 = pd.concat([to_remove16, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove16)
# Out:
# 1806

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
temp["text"].sample(n=50).to_list()
# Out:
# ["@WaterforHealth All GAIN ...No PAIN!  That's the way we mix it up! @sufficientc #diabetes #immunesystem #gerd https://t.co/pQ1DsE0NMH",
#  'Instead of taking an antacid medication how about if we heal the root cause?  Resolved! #GERD https://t.co/7OhglpQuWZ',
#  "Not an easy task even when you're healthy!\r\n#overcomingchallenges #GravesDisease #GERD #Arthritis #bipolar\r\n#amwriting https://t.co/oMQupr5cqs",
#  '#gerd diet menu divino shoes online shop',
#  '#Amazonia Heron\r\nMonotypePainting/Collage 2016\r\n#Amazonas #Nile\r\nA Letter to River Nile &gt; https://t.co/xhEmLrI0gm\r\nPROTECT AMAZONIA #WaterIsLife https://t.co/v76SwuqDw6',
#  "Woke up around 4 thinking I had to throw up. I didn't, but I couldn't get back to sleep either. Happy Wednesday. #gerd",
#  '#gerd diet free scully western wear online shop',
#  '#gerd diet mayo clinic fashion shopping online indonesia',
# ...

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y16.loc[y16["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y16.loc[y16["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates().copy()
junk16 = pd.concat([y16, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates(keep=False).copy()
print(len(junk16), len(y16), len(to_keep))
# Out:
# 7542 8997 1455

# %%
junk16.loc[junk16["created_at"].str.contains("2016-07")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]
# Out:
# ['The 7 best supplements for #GERD sufferers #IntelligentMedicine https://t.co/jRvYZDmmic',
#  'Millions of #Canadians are affected #IBS, #GERD, and #IBD.  Help us change lives by making a #donation! #socialgood https://t.co/EdAENg72LN',
#  'NEW #UBC TI Letter: Comparative effectiveness of proton pump inhibitors: https://t.co/j6TntCLd7g  #ptsafety #drugsafety #GERD #ulcers #ebhc',
#  "For all you #GERD sufferers, here's your Friday funny https://t.co/79znyrivxq",
#  "#Mosquitoes- 'Phenomenal' numbers in early tally; no #West #Nile detected in #Fremont #County yet https://t.co/A53JW01jPv",
#  'Blue Nile hits a 1 month high https://t.co/OMQugArgdR $NILE #BlueNile https://t.co/IvmXJLlhdd',
#  'English ceramics @LeverArtGallery made around the time #Napoleon &amp; Nelson were engaged in the Battle of the #Nile https://t.co/jcAB64zGMx',
#  'Bashir declares ceasefire in #BlueNile, #SouthKordofan https://t.co/un5UPs2aKe',
# ...

# %%
to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")]["text"].to_list()
# Out:
# ['#Ethiopia confirmed two Bottom outlets at #GERD will provide adequate amount of water to downstream countries #Egypt #Sudan @nilebasin',
#  'Turbulent waters: Egypt, Sudan and Ethiopia are struggling to share the Nile https://t.co/kairTghSOf #Ethiopia #Egypt #Sudan #GERD',
#  'Water politics: Sharing the Nile #Ethiopia #Sudan #Egypt #GERD https://t.co/7VGkNZknIp via @TheEconomist',
#  'Top OpEd on #GERD #Ethiopia #Egypt #Sudan debate &amp; why some media frame #international #river issues as "#waterwars" https://t.co/Ws7EXkZYM5',
#  'Wondered about water politics?here is a good piece on sharing  #Nile #GERD #Ethiopia #Egypt #Sudan https://t.co/52kNPFIZoi via @TheEconomist',
#  'Water politics : Sharing the Nile – Egypt, Sudan and Ethiopia | Diplomat News Network https://t.co/yrmWyt0NP8 #Ethiopia #Sudan #Egypt #GERD',
#  'Water Security in the Nile Basin  https://t.co/rr12L1uZkr #Ethiopia #GERD #Egypt #Sudan #Africa #Rwanda #Uganda #Kenya #Tanzania #Eritrea',
# ...

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove16, junk16]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 240990

# %% [markdown]
# ## 2017

# %%
y17 = ht.loc[ht["created_at"].str.lower().str.contains("2017")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove tigray

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")].copy()#["text"].to_list()
to_remove17 = y17.loc[y17["text"].str.lower().str.contains("tigray")]

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove17)
#r'^(?=.*tplf)(?=.*jewelry)'
# nilewater
# Out:
# 1189

# %%
y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*tigray)(?=.*dam)')]["text"].to_list()
# Out:
# ['The Greb Segen Dam for #Mekelle #Tigray for water supply to Mekelle &amp; irrigation https://t.co/eWm01qgr7H',
#  'Gereb Segen Dam for irrigation &amp; water supply of #Mekelle #Tigray #Ethiopia https://t.co/AtERfhHQIM',
#  'Visiting the gereb Segen dam - water supply and irrigation project #Mekelle #Tigray; many of us would like see water coming to Mekelle https://t.co/b85hOZNI1W',
#  "Let's go for sand dam; we will work to identify suitable areas @MekUniETH in #Tigray; impressed by works of REST #Hawzien &amp; needs scaling up https://t.co/bN4ptcGiTK",
#  'May Day dam for #Wolkayt sugar factory #Tigray; MU @MekUniETH is partnering with z corporation for research https://t.co/AQyGiunSmG',
#  '†♥† 1st &amp; for Most Amusing World Class Church Inside of #Tigray #Debre_DAMO †♥†\r\n†♥† ሌሊትና ቀን ቅዱስ ቅዱስ ቅዱስ እያሉ የሰራዊት... https://t.co/epYBpY2YY9',
# ...

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove17 = pd.concat([to_remove17, y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]]).copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove17)
# Out:
# 1212

# %%
#y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y17.loc[y17["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()

to_remove17 = pd.concat([to_remove17, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove17)
# Out:
# 1705

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
temp["text"].sample(n=50).to_list()
# Out:
# ['im seeing homeshake &amp; mac this friday #er #mah #gerd',
#  'Replenished #GERD #medicine and doctor added 2 new pills...\r\n#HaveFaith #LifeIsBetter… https://t.co/n2xJvYNCTg',
#  '"...most severe pain problems." https://t.co/kxp3UmKQvJ #InvisibleIllness #RA #OA #DDD #GERD #IBS #Lupus #Raynauds #somuchmore #MedicalZebra',
#  'Findings on #ART adherence in #HIV infected adults from #Tigray, #Ethiopia @GlobalHealthBMJ https://t.co/3MwfcQCvJI @HGodefay et al.',
#  '2 month update! \r\nhttps://t.co/W6hU3HpIzC\r\n#2monthupdate #2months #babygirl #gerd #silentreflux #2months #familyvloggers #youtuber https://t.co/5E5mF6b3wx',
#  '@disease_lyme @confine2success Can definitely relate 2 this one😧 #RheumatoidDisease #Fibro #Psoriaticarthritis  #Osteoarthritis #GERD #PTSD #panicattack &amp; the list goes on',
#  '#HappyThanksgiving Beat the "Burn" This Holiday Season - YouTube @AmerGastroAssn #GERD  https://t.co/0Qa93kEOdB',
# ...

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y17.loc[y17["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates().copy()
junk17 = pd.concat([y17, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10]).drop_duplicates(keep=False).copy()
print(len(junk17), len(y17), len(to_keep))
# Out:
# 6422 8068 1646

# %%
#junk17.loc[junk17["created_at"].str.contains("2017-04")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]

# %%
to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")]["text"].to_list()
# Out:
# ["#Sudane's president attends for installation of the 1st Turbine for Atbara #Dam .#nilebasin #WaterDiplomacy #GERD #Egypt #Ethiopia @nbiweb https://t.co/B1QQDyPAWr",
#  "#Ethiopia's ; #GERD #PublicDiplomacy Bearing Fruits.#Sudan #Egypt #Kenya #Tanzania #Uganda #Brundi #Congo #Rwanda @waterdiplomacy @FasilAGM https://t.co/wHu3Lv5sQS",
#  '@anacascao discussing with Journalists from ethiopia Egypt Sudan trained by @siwi_water on  #nile and #gerd https://t.co/iRgMcq6BMX',
#  "How &amp; why #Ethiopia's strategy on #GERD Dam succeded By #Sudanese  #Water expert @WorldBank; @Jadwong @nib @temaden  https://t.co/c4fTcEYfm5",
#  '#Sudan\'s #water minster "#GERD wont affect  Devpt of  whole #Nilebasin countries" as the study continues on it. @zerubeeb @AndersJagerskog https://t.co/5rz5Wqz8vO',
#  "#Ethiopia's #GERD dam well  Designed to manage future flow &amp; floods of #Nile #water in #Sudan @TheRealOlaDiab @Sudan_Voices @NesrineMalik https://t.co/DQaipeFWbJ",
# ...

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove17, junk17]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 234527

# %% [markdown]
# ## 2018

# %%
y18 = ht.loc[ht["created_at"].str.lower().str.contains("2018")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove18 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')].copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove18)
# Out:
# 5

# %%
#y17.loc[y17["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y18.loc[y18["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()

to_remove18 = pd.concat([to_remove18, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove18)
# Out:
# 644

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
temp["text"].sample(n=50).to_list()
# Out:
# ['This episode: How to eat to calm your #GERD and #IBS. #powerhouseIBSconqueror #IBSdiet #GERDdiet https://t.co/5EIldI2Oyr',
#  'https://t.co/lbzfTta71U\r\n\r\n#Evewin #Lakra - #Nescafe - #Cafe - #Latte - #Coffee - #Review\r\n\r\n#NescafeCoffee\r\n#CoffeeReview\r\n#best #coffee\r\n#Good Coffee \r\nbest coffee in #India\r\n#Product #Review\r\n#ProductReview\r\n\r\n#Le-Figaro #Mosquito #Racket\r\n#Aristocrat #Nile #Polyester #Luggage #Bag',
#  "If an insurance company is forcing you (or your patient) to live with intractable #GERD following a #sleeve gastrectomy, we are able to help. CALL US TOLL FREE at 877-992-7732 to discuss the options. You don't have to live with terrible #GERD just because your insurer says so!",
# ...

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y18.loc[y18["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()
to_keep11 = y18.loc[y18["text"].str.lower().str.contains(r'^(?=.*tigray)(?=.*gerd)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates().copy()
junk18 = pd.concat([y18, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates(keep=False).copy()
print(len(junk18), len(y18), len(to_keep))
# Out:
# 7723 10808 3085

# %%
#junk17.loc[junk17["created_at"].str.contains("2017-04")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]

# %%
to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")].sample(n=50)["text"].to_list()
# Out:
# ['This is how some people in #Ethiopia view the #GERD(nile dam) sad but true  #Ethiopia #Eritrea #Egypt https://t.co/YdKMOzHyKm',
#  'Grand Ethiopian Renaissance Dam (GERD): Negotiations are at risk as #Egypt proposes #Sudan out of the largest hydroelectric dam project in @Africa - @AJENews https://t.co/71gieKrO1o\r\n\r\n👉Learn more about the #GERD accessing @iwra_water webinar here:  https://t.co/TMeZi0Mp7i https://t.co/9tG5fihD4P',
#  '💧 Ethiopia has not yet started filling #GERD: Minister - https://t.co/FWxsqy3ErH #EgyptToday #Ethiopia #Sudan #Egypt #Nile #water https://t.co/3eDVLrI4KT',
#  "#Ethiopia PM Abiy Ahmed's #Medemer tour to #Egypt before they assassinated our #GERD chief Engineer Semegnew Bekele  https://t.co/mYj002Z07b",
# ...

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove18, junk18]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 226773

# %% [markdown]
# ## 2019

# %%
y19 = ht.loc[ht["created_at"].str.lower().str.contains("2019")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove19 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')].copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove19)
# Out:
# 12

# %%
#y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y19.loc[y19["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()

to_remove19 = pd.concat([to_remove19, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove19)
# Out:
# 676

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
temp.loc[temp["text"].str.lower().str.contains("renaissance")]["text"].to_list()
# Out:
# ["The #Nile River's massive, long-awaited Grand Ethiopian Renaissance Dam  should generate its first power by the end of 2020.\r\nMore info from @Enerdata 's Daily Energy News: https://t.co/UBu8EjYVXp \r\n#Ethiopia #EnergyTransition \r\n#HydroPower"]

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y19.loc[y19["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()
to_keep11 = y19.loc[y19["text"].str.lower().str.contains(r'^(?=.*tigray)(?=.*gerd)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates().copy()
junk19 = pd.concat([y19, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates(keep=False).copy()
print(len(junk19), len(y19), len(to_keep))
# Out:
# 8938 11233 2295

# %%
#junk17.loc[junk17["created_at"].str.contains("2017-04")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]

# %%
#to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")].sample(n=50)["text"].to_list()

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove19, junk19]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 217810

# %% [markdown]
# ## 2020

# %%
y20 = ht.loc[ht["created_at"].str.lower().str.contains("2020")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove20 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')].copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove20)
# Out:
# 29

# %%
#y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y20.loc[y20["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|treatment|throwing up|lactose|asthma|implant|beer|nutrition|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
temp = pd.concat([temp, temp.loc[temp["text"].str.lower().str.contains("renaissance|itsmydam|itsourdam|itsherdam|nile4all|fillthedam|fillthegerd|finishthegerd")]]).drop_duplicates(keep=False).copy()

to_remove20 = pd.concat([to_remove20, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove20)
# Out:
# 792

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
len(temp.loc[temp["text"].str.lower().str.contains("renaissance|itsmydam|itsourdam|itsherdam|nile4all|fillthedam|fillthegerd|finishthegerd")]["text"].to_list())
# Out:
# 177

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y20.loc[y20["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()
to_keep11 = y20.loc[y20["text"].str.lower().str.contains(r'^(?=.*tigray)(?=.*gerd)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates().copy()
junk20 = pd.concat([y20, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates(keep=False).copy()
print(len(junk20), len(y20), len(to_keep))
# Out:
# 21642 51806 30164

# %%
#junk17.loc[junk17["created_at"].str.contains("2017-04")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]

# %%
#to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")].sample(n=50)["text"].to_list()

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove20, junk20]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 196005

# %% [markdown]
# ## 2021

# %%
y21 = ht.loc[ht["created_at"].str.lower().str.contains("2021")].copy()#["text"].to_list()

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove21 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')].copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove21)
# Out:
# 5

# %%
#y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()
# Out:
# ["Death toll from violence in Sudan's West Darfur rises to 83 - ABC News #Ethiopia #USA #Darfur #Bluenile #kordofan #Sudan #GERD https://t.co/lzoBA5J4Ff",
#  'On March 1, #PEJ Legal Consultant Nina Mann was interviewed by @jayfidell for @thinktechhi. Nina spoke about her work &amp; PEJ’s work in #SouthKordofan and #BlueNile States of #Sudan as part of the #TransitionalJustice series. #HumanRights #ACERWC\r\nhttps://t.co/yk0izMSTmn',
#  "@EgyptsNo1 @SecBlinken #Egypt is z #sickman of #Africa, as it aides and abates many warring factions everywhere from #Darfur, #Kordofan, #BlueNile in #Sudan to z degenerates of the Lord's Resistance Army in #Uganda etc. Add #Atta &amp; z blind shekih, they need to be on a leash. Z #GERD can serve as one.",
# ...

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y21.loc[y21["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|treatment|throwing up|lactose|asthma|implant|beer|nutrition|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
temp = pd.concat([temp, temp.loc[temp["text"].str.lower().str.contains("renaissance|itsmydam|itsourdam|itsherdam|nile4all|fillthedam|fillthegerd|finishthegerd")]]).drop_duplicates(keep=False).copy()

to_remove21 = pd.concat([to_remove21, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove21)
# Out:
# 882

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
#len(temp.loc[temp["text"].str.lower().str.contains("renaissance|itsmydam|itsourdam|itsherdam|nile4all|fillthedam|fillthegerd|finishthegerd")]["text"].to_list())
# Out:
# 177

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y21.loc[y21["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()
to_keep11 = y21.loc[y21["text"].str.lower().str.contains(r'^(?=.*tigray)(?=.*gerd)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates().copy()
junk21 = pd.concat([y21, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates(keep=False).copy()
print(len(junk21), len(y21), len(to_keep))
# Out:
# 20863 103614 82751

# %%
#junk17.loc[junk17["created_at"].str.contains("2017-04")]["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]

# %%
#to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")].sample(n=50)["text"].to_list()

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove21, junk21]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 174896

# %% [markdown]
# ## 2022

# %%
y22 = ht.loc[ht["created_at"].str.lower().str.contains("2022")].copy()#["text"].to_list()
len(y22)
# Out:
# 46787

# %% [markdown]
# ### Remove sudan+kordofan

# %%
to_remove22 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')].copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove22)
# Out:
# 8

# %%
#y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*kordofan)')]["text"].to_list()
# Out:
# ['After 10 years of research, my new #Sudan article shows that #Humanitarian #Intervention has backfired by perpetuating #CivilWar in the #TwoAreas of #SouthKordofan and #BlueNile https://t.co/fdak9wDIAg',
#  "#USAIDSudan's Sustainable AgriFood Systems Approach is in collaboration with @CGIAR &amp; @CIMMYT to improve yields &amp; income for smallholder farmers in #BlueNile, #SouthKordofan &amp; areas around #Khartoum.",
#  'Inter-communal and localized violence in #Sudan have escalated since the military coup in October 2021, particularly in #Darfur, #Kordofan and #BlueNile. \r\n\r\nAccording to @UNOCHA_Sudan an unconfirmed 170 people have been killed and 327 injured in Wad Al Mahi, Blue Nile. https://t.co/KXLFXwLLIy',
#  'At least 150 dead in renewed tribal war in Sudan #InterethnicConflicts #Sudan #BlueNile #Damazine #Southend #Knutsford #WestKordofanState #AfricaNews   https://t.co/A9Wnwn3RvD',
# ...

# %% [markdown]
# ### Remove wrong gerd-related stuff

# %%
temp = y22.loc[y22["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|treatment|throwing up|lactose|asthma|implant|beer|nutrition|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
temp = pd.concat([temp, temp.loc[temp["text"].str.lower().str.contains("renaissance|itsmydam|itsourdam|itsherdam|nile4all|fillthedam|fillthegerd|finishthegerd")]]).drop_duplicates(keep=False).copy()

to_remove22 = pd.concat([to_remove22, temp]).drop_duplicates().copy()#["text"].to_list()

#ht = pd.concat([ht, to_remove12]).drop_duplicates(keep=False).copy()
len(to_remove22)
# Out:
# 809

# %%
#temp = y14.loc[y14["text"].str.lower().str.contains("pain|symptom|tablet|throat|recipes|paulbuchanan|medicine|er #mer #gerd|erma #gerd|yacht|sick|spice|chocolate|bowel|gastritis|losing weight|prilosec|müller|muller|bloating|constipation|diarrhea|probiotic|breakfast|coffee|ulcer|geek|nerd|adidas|diet|sleep|lowcarb|er #mah #gerd|eh #mah #gerd|wholefoods|tortilla|hospital|asparagus|patient|treatment|throwing up|lactose|asthma|implant|beer|nutrition|chronic|weightloss|digestion|garlic|medication|gastro|crohns|fibro|health|cancer|reflux|ph test|smoothie|dentist")]#["text"].to_list()
#len(temp)

#temp["text"].to_list()

# %%
#len(temp.loc[temp["text"].str.lower().str.contains("renaissance|itsmydam|itsourdam|itsherdam|nile4all|fillthedam|fillthegerd|finishthegerd")]["text"].to_list())
# Out:
# 177

# %%
#test = pd.concat([y13, temp]).drop_duplicates(keep=False).copy()
#len(test)
#test.loc[test["text"].str.lower().str.contains("gerd")]["text"].to_list()

# %%
#y13.loc[y13["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')]["text"].to_list()

# %% [markdown]
# ### Further

# %%
#y12 = ht.loc[ht["created_at"].str.lower().str.contains("2012")]#["text"].to_list()
to_keep1 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*sudan)(?=.*water)')].copy()
to_keep2 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*water)')].copy()
to_keep3 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*ethiopia)(?=.*water)')].copy()
to_keep4 = y22.loc[y22["text"].str.lower().str.contains("dams|renaissance|millennium|watersecurity|water security|nile basin|#cfa|nbcfa|framework|hydro|sharing|nilebasin|basin|construction|treaty|resource|politics|cooperation|electricity")].copy()
to_keep5 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*build)')].copy()
to_keep6 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*dam)(?=.*ethiopia)')].copy()
to_keep7 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*egypt)(?=.*ethiopia)')].copy()
to_keep8 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*ethiopia)')].copy()
to_keep9 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*egypt)')].copy()
to_keep10 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*gerd)(?=.*sudan)')].copy()
to_keep11 = y22.loc[y22["text"].str.lower().str.contains(r'^(?=.*tigray)(?=.*gerd)')].copy()

to_keep = pd.concat([to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates().copy()
junk22 = pd.concat([y22, to_keep1, to_keep2, to_keep3, to_keep4, to_keep5, to_keep6, to_keep7, to_keep8, to_keep9, to_keep10, to_keep11]).drop_duplicates(keep=False).copy()
print(len(junk22), len(y22), len(to_keep))
# Out:
# 12679 46787 34108

# %%
junk22.loc[junk22["created_at"].str.contains("2022-04-01")]#["text"].to_list()
#.loc[junk13["text"].str.lower().str.contains("africa")]
# Out:
#         Unnamed: 0                created_at                   id  \
# 161131      161131  2022-04-01T23:29:15.000Z  1510036600872308737
# 161132      161132  2022-04-01T20:51:06.000Z  1509996800417144841
# 161135      161135  2022-04-01T20:09:28.000Z  1509986325386215446
# 161136      161136  2022-04-01T14:35:48.000Z  1509902352198873161
# 161138      161138  2022-04-01T18:26:22.000Z  1509960378230398984
# 161139      161139  2022-04-01T18:22:28.000Z  1509959397279256577
# 161140      161140  2022-04-01T18:10:47.000Z  1509956455084011526
# 161143      161143  2022-04-01T17:48:00.000Z  1509950720820367361
# 161144      161144  2022-04-01T12:51:09.000Z  1509876016340160518
# 161145      161145  2022-04-01T17:10:37.000Z  1509941315483676686
# 161148      161148  2022-04-01T16:20:16.000Z  1509928642297667626
# 161149      161149  2022-04-01T13:20:47.000Z  1509883477117837314
# 161150      161150  2022-04-01T12:56:07.000Z  1509877267794645000
# ...

# %%
#to_keep.loc[to_keep["text"].str.lower().str.contains("gerd")].sample(n=50)["text"].to_list()

# %% [markdown]
# ### Remove above

# %%
ht = pd.concat([ht, to_remove22, junk22]).drop_duplicates(keep=False).copy()
len(ht)
# Out:
# 162008

# %% [markdown]
# ## Save

# %%
#ht.drop(columns=["Unnamed: 0"]).to_csv("data/filter/en/filtered_data0604.csv", index=False)
